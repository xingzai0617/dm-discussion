# %% [markdown]
# # Just Try
# - first of all: balabala
# - then : $a^2+b^2=c^2$

# %%
# %pylab
# %matplotlib inline

# %%
m=imread('lena.tif')
imshow(m,cmap='gray')
save('lena',m)

# %%
x = np.linspace(0, 20, 1000) 
y = np.sin(x)
plot(x,y)
savefig('sine.png')

# %%
# !ls -la
# Out:
# total 728
# drwxr-xr-x  8 crackhopper  staff    272  5  6 15:16 .
# drwxr-xr-x  9 crackhopper  staff    306  5  6 15:02 ..
# drwxr-xr-x  3 crackhopper  staff    102  5  6 15:15 .ipynb_checkpoints
# -rw-r--r--  1 crackhopper  staff  80519  5  6 15:14 jupyter-basis.ipynb
# -rw-r--r--  1 crackhopper  staff  90080  5  6 15:16 lena.npy
# -rw-r--r--  1 crackhopper  staff  90080  5  6 15:16 lena.pkl.npy
# -rwxr-xr-x@ 1 crackhopper  staff  90291  1 15  2001 lena.tif
# -rw-r--r--  1 crackhopper  staff  12845  5  6 15:16 sine.png

# %%
lena=load('lena.npy')
imshow(lena,cmap='gray')

# %%
imsave('lena.jpg',lena,cmap='gray')

# %%
# !ls
# Out:
# jupyter-basis.ipynb lena.npy            lena.tif
# lena.jpg            lena.pkl.npy        sine.png
